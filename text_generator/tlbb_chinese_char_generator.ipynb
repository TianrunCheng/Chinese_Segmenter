# %%
###############################################################################
# rnn (recurrent neural net) character language model
###############################################################################
import time, os, sys, random, datetime, math
import pickle
import argparse
import numpy as np
#import matplotlib.pyplot as plt

import torch
import torch.nn as nn

###############################################################################
use_cuda = torch.cuda.is_available()
print(torch.version.__version__, use_cuda)
###############################################################################
def cuda(arr):
    if use_cuda:
        return arr.cuda()
    return arr

###############################################################################
global log_file
global CharDict
global CharList
global CharWeight
global cover_list

CharDict = dict()
CharList = []
cover_list = ['\n','\t', '　',' ', '（', '）', '1', '2', '3', '4', '5', '6', '7', '8', '9', '0', '“','”','…','‘']

###############################################################################
# tunable hyper-parameters - default values
###############################################################################
# these values are used to create the model
###############################################################################
# character embedding
char_embed_size = 30

# recurrent layers
rnn_size = 300
# rnn_size = 400 # dimension of hidden layer
rnn_nLayers = 2

RNN_layers = [rnn_size, rnn_nLayers]

# feed-forward layers
layer0 = 128
layer1 = 64
layer2 = 128

layer3 = 100
layer4 = 100

FFNN_layers = [layer0, layer1, layer2]
#FFNN_layers = [layer0, layer1, layer2, layer3]
#FFNN_layers = [layer0, layer1, layer2, layer3, layer4]

dropout = 0.0
dropout = 0.1

###############################################################################
# these values are used within the training code
###############################################################################
global learning_rate
global batch_size
global chunk_size
global nEpochs
global L2_lambda
global Max_Vocab

Max_Vocab = 3600

learning_rate = 0.0001
learning_rate = 0.0003
# learning_rate = 0.001
# learning_rate = 0.003

batch_size = 5
batch_size = 20
# batch_size = 100

chunk_size = 50
chunk_size = 100
# chunk_size = 200

#nEpochs = 1
nEpochs = 2
nEpochs = 10
nEpochs = 200
#nEpochs = 1000

L2_lambda = 0.0
# L2_lambda = 0.002

###############################################################################
class RNN(nn.Module):
###############################################################################
    def __init__(self, specs):
        super(RNN, self).__init__()

        nChars, embed_size, rnn_layers, ffnn_layers, dropout = specs
        self.CharEmbed = nn.Embedding(nChars, embed_size)

        rnn_size, rnn_nLayers = rnn_layers
        self.rnn = nn.GRU(embed_size, rnn_size, rnn_nLayers, dropout=dropout, batch_first = True)
        # self.rnn = nn.RNN(embed_size, rnn_size, rnn_nLayers, dropout=dropout, batch_first = True)
        # self.rnn = nn.LSTM(embed_size, rnn_size, rnn_nLayers, dropout=dropout, batch_first = True)

        self.layers = nn.ModuleList([])
        prev_size = rnn_size
        for i, layer_size in enumerate(ffnn_layers):
            layer = nn.Linear(prev_size, layer_size)
            self.layers.append(layer)
            prev_size = layer_size

        self.out = nn.Linear(prev_size, nChars) # character - CrossEntropy

        self.non_linear = nn.LeakyReLU(negative_slope=0.01)
        
        self.dropout = nn.Dropout(dropout)

        for p in self.parameters(): # optionally apply different randomization
            if p.dim() > 1:
                nn.init.kaiming_normal_(p)
                pass

    #################################################################
    def forward(self, seqs, hidden=None):
        # input is a list of sequences of torch longs already on cuda as needed
        nBatch = len(seqs)
        nChars = len(seqs[0])

        seqs = torch.cat(seqs).view(nBatch, nChars)

        embed = self.CharEmbed(seqs)

        prev, hidden = self.rnn(embed, hidden)

        #print(prev.size())

        for layer in self.layers:
            prev = layer(prev)
            prev = self.non_linear(prev)
            prev = self.dropout(prev)

        out = self.out(prev) # chars
        # print(out.size())
        #hidden = torch.transpose(hidden, 0, 1)
        return out, hidden

###############################################################################
def RNN_train(model, optimizer, criterion, chunks, update=True):
    model.zero_grad()
    loss = 0
    nFrames = 0

    out, hidden = model(chunks)

    skip = 5
    nBatch = len(chunks)   
    for i in range(nBatch):
        loss += criterion(out[i][skip-1:-1,:], chunks[i][skip:])
        nFrames += len(chunks[i]) - skip

    if update:
        if not loss is 0:
            loss.backward()
            optimizer.step()

    return loss.data.item(), nFrames

###############################################################################
def train_rnn_model(model, data_train, data_dev=None):
    if use_cuda:
        model = model.cuda()

    # define the loss functions
    criterion = nn.CrossEntropyLoss(reduction='sum', weight = CharWeight)

    # choose an optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=L2_lambda)

    data_len = len(data_train) - chunk_size
    nLoops = 1 + len(data_train) // (batch_size * chunk_size)

    results = []

    start_time = time.time()
    for e in range(nEpochs):
        train_frames = 0
        train_loss = 0
        model.train()
        for i in range(nLoops):
            chunks = []
            for j in range(batch_size):
                start = np.random.randint(data_len)
                chunks.append(data_train[start:start+chunk_size])
        
            loss, nFrames = RNN_train(model, optimizer, criterion, chunks, update=True)
          
            train_frames += nFrames
            train_loss += loss
            # print("%2d %6d %8.3f" % (e, (i+1)*batch_size*chunk_size, loss/nFrames))

        print(train_frames, train_loss, train_loss / train_frames)
        sample = generate(model, seed="这", n=100)
        print('epoch'+ str(e) + '#  ' +sample)

        dev_frames = 0
        dev_loss = 0
        if not data_dev is None:
            model.eval()
            chunks = []
            for start in range(0, len(data_dev)-chunk_size, chunk_size):
                chunks.append(data_dev[start:start+chunk_size])

            dev_loss, dev_frames = RNN_train(model, optimizer, criterion, chunks, update=False)

        # if dev_frames == 0: dev_frames = 1
        # log_message(log_file, "%3d %8d %8.3f\t%8d %8.3f\t%6.1f" % (e, train_frames, \
        #               train_loss/train_frames, dev_frames, dev_loss/dev_frames, (time.time()-start_time)))

    # torch.save(model, 'model/charlm-temp.pth')

    return model

###############################################################################
def log_message(outf, message):
    print(message)
    if not outf is None:
        outf.write(message)
        outf.write("\n")
        outf.flush()

def generate(model, seed="The ", n=100):
    model.eval()
    ndx_data = cuda(convert_data(seed, CharDict))
    c, h = model([ndx_data])
    text = list(seed)
    for i in range(n):
        scores = c[0,-1]
        _, best = scores.max(0)
        best = best.data.item()
        text.append(CharList[best].char)
        c_in = cuda(torch.LongTensor([best]))
        c, h = model([c_in], h)

    return ''.join(text)

# input a list of chars, output a tensor made of index of chars
def convert_data(data, CharDict, quit_early=0):
    start = time.time()
    if quit_early > 0:
        data = data[:quit_early]
    
    ndx_data = torch.zeros(len(data), dtype=torch.long)

    for i, c in enumerate(data):
        #print(i, c)
        ndx_data[i] = CharDict[c].ndx

    return ndx_data

###############################################################################
class TextConverter:
    def __init__(self, text_path, max_vocab=Max_Vocab):
        with open(text_path, 'r') as f:
          text = f.read()
        data = text
        text = []
        for c in data:
          if c not in cover_list:
            text.append(c)

        vocab = set(text)
        vocab_count = {}

        for word in vocab:
          vocab_count[word] = 0
        for word in text:
          vocab_count[word] += 1
        vocab_count_list = []
        for word in vocab_count:
          vocab_count_list.append((word, vocab_count[word]))
        vocab_count_list.sort(key=lambda x:x[1], reverse=True)

        avg_count = len(text) / len(vocab_count_list)
        vocab_count_list = vocab_count_list[:max_vocab]
        num_val = 0
        for num in vocab_count_list:
          num_val += num[1]
        
        self.weight = []
        for x in vocab_count_list:
          # self.weight.append(math.sqrt(avg_count/x[1]))
          self.weight.append(math.pow(avg_count/x[1], 0.3))
        self.weight.append(math.sqrt(avg_count/(len(text)-num_val)))
        
        vocab = [x[0] for x in vocab_count_list]
        self.vocab = vocab

        self.word_to_int_table = {c: i for i, c in enumerate(self.vocab)}
        self.int_to_word_table = dict(enumerate(self.vocab))
      
    def vocab_size(self):
      return len(self.vocab) + 1

    def word_to_int(self, word):
      if word in self.word_to_int_table:
        return self.word_to_int_table[word]
      else:
        return len(self.vocab)
    
    def int_to_word(self, index):
      if index == len(self.vocab):
        return '<unk>'
      elif index < len(self.vocab):
        return self.int_to_word_table[index]
      else:
        raise Exception('Unknown index!')
    
    def text_to_arr(self, text):
      arr = []
      for word in text:
        arr.append(self.word_to_int(word))
      return np.array(arr)

    def arr_to_text(self, arr):
      words = []
      for index in arr:
        words.append(self.int_to_word(index))
      return ''.join(words)


class Char:
    def __init__(self, char):
        self.char = char
        self.ndx = None  # the index number of this char
        self.count = 0

###############################################################################
# start main
###############################################################################
global convert 
convert = TextConverter('./tlbb.txt')

for i in range(convert.vocab_size()):
  c = convert.int_to_word(i)
  char = Char(c)
  char.ndx = i
  CharDict[c] = char
  CharList.append(char)

# char = Char('<unk>')
# char.ndx = convert.word_to_int(c)
# CharDict['<unk>'] = char
# CharList.append(char)

CharWeight = torch.zeros(len(CharList), dtype=torch.float)
for i in range(len(convert.weight)):
  CharWeight[i] = convert.weight[i]
  # CharWeight[i] = 1
CharWeight[-1] = 0
CharWeight = cuda(CharWeight)
for i in range(10):
  print(CharList[i].char)
  print(CharWeight[i])
print(CharList[-2].char)
print(CharWeight[-2])
print(CharList[-1].char)
print(CharWeight[-1])
# CharList is a int to char table, with 0th item being ndx=0 char (of class Char)

with open('tlbb.txt', 'r') as f:
  corpus = f.read()
data = corpus
corpus = []
for c in data:
  if c not in cover_list:
    corpus.append(c)

# corpus = corpus[:500000]

train_data = convert.text_to_arr(corpus)
ndx_train_data = torch.from_numpy(train_data)
ndx_train_data = cuda(ndx_train_data)
nChars = convert.vocab_size()
specs = [nChars, char_embed_size, RNN_layers, FFNN_layers, dropout]
model = RNN(specs)
print(model)

train_rnn_model(model, ndx_train_data, data_dev=None)
# Out:
# 1.4.0 True
# ，
# tensor(0.1783, device='cuda:0')
# 。
# tensor(0.2523, device='cuda:0')
# 不
# tensor(0.2767, device='cuda:0')
# 一
# tensor(0.2824, device='cuda:0')
# 的
# tensor(0.2837, device='cuda:0')
# 是
# tensor(0.2934, device='cuda:0')
# 道
# tensor(0.2992, device='cuda:0')
# 了
# tensor(0.3000, device='cuda:0')
# ：
# tensor(0.3013, device='cuda:0')
# 人
# tensor(0.3183, device='cuda:0')
# 悭
# tensor(4.3816, device='cuda:0')
# <unk>
# tensor(0., device='cuda:0')
# RNN(
#   (CharEmbed): Embedding(3601, 30)
#   (rnn): GRU(30, 300, num_layers=2, batch_first=True, dropout=0.1)
#   (layers): ModuleList(
#     (0): Linear(in_features=300, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=64, bias=True)
#     (2): Linear(in_features=64, out_features=128, bias=True)
#   )
#   (out): Linear(in_features=128, out_features=3601, bias=True)
#   (non_linear): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 1105800 5095559.920410156 4.608030313266554
# epoch0#  这，这一一，你一，你一，你一，你你这，你你你你你你你你你你你你你你你你你你我我我你不你不不，你我你你你你你我我你你你你你你我我你你你你你你你我我你我你你你你你你你你你你你你你我我我你你你你你你你我我你我
# 1105800 4738755.005371094 4.285363542567457
# epoch1#  这些人一个，只是我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知不能，我不知
# 1105800 4503752.71484375 4.0728456455450806
# epoch2#  这些人的一个女子，只是这些人的一声，只是这些人的一声，只是这些人的一声，只是这些人的一声，只是这些人的一声，只是这些人的一声，只是这些人的一声，只是这些人的一声，只是这些人的一声，只是这些人的一声，只是
# 1105800 4359319.520996094 3.9422314351565326
# epoch3#  这般一个人，只是我们不知他们不知我？他们也不知我不知我？他们也不知我不知我？他们也不知我？他们也不知我不知我？他们也不知我？他们也不知我不知我？他们也不知我？他们也不知我不知我？他们也不知我？他们也不知
# 1105800 4226769.585449219 3.822363524551654
# epoch4#  这般大理，你们也不能不能，我这么？那女郎道：你是你们是我？你是我们你们是我？你是我们你们是我？你是我们你们是我们是你，你你你不是我？你是我们你们是我们我们我们我们我们我们我们我们我们我们我们我们我们我们
# 1105800 4131454.1411132812 3.736167608169001
# epoch5#  这般，但只是我们，我们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们也不知他们
# 1105800 4063603.9018554688 3.6748090991639253
# epoch6#  这般是谁？段誉道：你们也不肯不是？段誉道：你们也不肯不是？段誉道：你们也不肯不是？段誉道：你们也不肯不是？段誉道：你们也不肯不是？段誉道：你们也不肯不是？段誉道：你们也不肯不是？段誉道：你们也不肯不是？
# 1105800 3994261.6098632812 3.612101293057769
# epoch7#  这般是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们
# 1105800 3944689.1953125 3.567271835153283
# epoch8#  这般是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们
# 1105800 3895108.7373046875 3.5224351033683194
# epoch9#  这些人也不敢再不过去。段誉道：你们也不能能能能够有什么？段誉道：你们也不肯不肯不肯不肯不敢杀了。段誉道：你们也不能能能能够有什么？段誉道：你们也不肯不肯不肯不肯不敢杀了。段誉道：你们也不能能能能够有什么
# 1105800 3841900.4443359375 3.474317638213002
# epoch10#  这般是谁？段誉道：你们也不能能能能够，我不是我，我们也不能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能能
# 1105800 3791232.6669921875 3.428497618911365
# epoch11#  这般是谁？段誉道：你们说话，我们也不能杀了。段誉道：你们说话，我们也不能杀了。段誉道：你们说话，我们也不能杀了。段誉道：你们说话，我们也不能杀了。段誉道：你们说话，我们也不能杀了。段誉道：你们说话，我们
# 1105800 3777426.3393554688 3.4160122439459837
# epoch12#  这般一个人物，只是一个女子，只见他身形，一个人向他胸膛，一个一个大恶人，说道：你们也不能杀了。段誉道：你怎么不肯杀了？段誉道：你怎么不肯杀了？段誉道：你怎么不肯杀了？段誉道：你怎么不肯杀了？段誉道：你怎
# 1105800 3729138.9194335938 3.372344835805384
# epoch13#  这般一个人，但这些人也不能够，但是我们的人物，我也不能再说。段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 3700878.2104492188 3.3467880362174163
# epoch14#  这般一个字，只是一个女子，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 3682890.1591796875 3.3305210338032984
# epoch15#  这般一个字，只是一个女子，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 3645013.083984375 3.2962679363215543
# epoch16#  这般一个人物，但见他一个女子，只见他右手抓住他胸膛，便即向他胸口，一股一阵，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你
# 1105800 3624739.791015625 3.277934338049941
# epoch17#  这般一个人物，却也不敢贸然，但见他一个踉跄，一个踉跄，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道
# 1105800 3606533.5024414062 3.26146997869543
# epoch18#  这般一个字画，但见他一个女子，只见他左手抓住了一条，便即向他胸膛，一股一阵，便即向他胸膛，一股一阵，便即向他手腕，一股一团，便即向他手腕，一股一团，便即向他手腕，一股一团，便即向他手腕，一股一团，便即向
# 1105800 3582122.6396484375 3.2393946822648196
# epoch19#  这般一个字，只是不敢贸然，但见他一个女子，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 3558373.85546875 3.217918118528441
# epoch20#  这般一个人物，只怕我们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我
# 1105800 3550643.3120117188 3.2109272128881523
# epoch21#  这般一个人，但这些人都是我们，我们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 3538582.3686523438 3.2000202284792403
# epoch22#  这般一个字画，但见他一个踉跄，一股一阵，一柄飞舞，一柄钢杖，一柄飞舞，一柄钢杖，一柄飞舞，一柄钢杖，一柄飞舞，一柄钢杖，一柄飞舞，一柄钢杖，一柄飞舞，一柄钢杖，一柄飞舞，一柄钢杖，一柄飞舞，一柄钢杖，一
# 1105800 3501598.73046875 3.166575086334554
# epoch23#  这般一个字画，但见他一个踉跄，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段
# 1105800 3495398.0766601562 3.160967694574205
# epoch24#  这般一个字画，但见他身上，只见他身上一阵麻核，便是一条绿杉，一个女子，只见他身上一阵麻核，便是一条绿杉，一个女子，只见他身上一条绿杉，一柄钢锥，一柄盾牌的剑尖，便即挥抓，只见他左手抓住了他胸膛，便即跃起
# 1105800 3481806.72265625 3.1486767251367787
# epoch25#  这般一个字画，但见他一个踉跄，一个踉跄，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你
# 1105800 3456575.4780273438 3.12585953882017
# epoch26#  这般一个字画，但见他一个踉跄，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段
# 1105800 3451060.40625 3.1208721344275636
# epoch27#  这般一个字画，但见他一阵麻核，却也不敢贸然，只见他一阵麻核，一股劲力，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 3422053.748046875 3.094640756056136
# epoch28#  这般一个女子，便即是一个女子，便即是一个女子，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是
# 1105800 3420213.2846679688 3.09297638331341
# epoch29#  这般一个女子，却也不敢贸然不知，但是不会不是？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们
# 1105800 3401885.673828125 3.0764023094846493
# epoch30#  这般一个字画，但见他身子一晃，便即停步，便即停步，说道：你们是谁？你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 3391867.541015625 3.0673426849481147
# epoch31#  这般一个字画，但见他身上，只觉一股劲风，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你
# 1105800 3376817.3583984375 3.053732463735248
# epoch32#  这般一个字画，但见他身上，只觉一股劲风，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你
# 1105800 3361718.5625 3.040078280430458
# epoch33#  这般一个字画，但见他身上，只觉一股劲风，便即停步，说道：你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是
# 1105800 3364493.0302734375 3.04258729451387
# epoch34#  这般一个字画，但见他身子一晃，便即摔在地下，只见他右手抓住他腰间，只见他右手抓住他腰间，只见他右手抓住他腰间，只见他右手抓住他腰间，只见他右手抓住他腰间，只见他右手抓住他腰间，只见他右手抓住他腰间，只见
# 1105800 3346053.1069335938 3.0259116539460966
# epoch35#  这般一个女子，便即是我，我们也不是我，你不是你，你不是你的，你不是你的？段誉道：你们不知他们的话，你们还是是我的孩儿，你不是你的？段誉道：你们不知他们的话，你们还是是我的孩儿，你不是你的？段誉道：你们不
# 1105800 3337231.6411132812 3.0179342024898546
# epoch36#  这般一个字画，只觉一股劲风，便即停步，便即伸手按住了他胸膛，只见他右手抓住他胸膛，便即向他胸膛，便向他胸膛，便向他胸膛，便向他胸膛，便向他胸膛，便向他胸膛，便向他胸膛，便向他胸膛，便向他胸膛，便向他胸膛
# 1105800 3329890.396484375 3.0112953486022564
# epoch37#  这般一个字画，只觉一股鲜血淋漓，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 3316240.1752929688 2.9989511442331063
# epoch38#  这般一个字画，只怕我们这般是我们，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不
# 1105800 3308462.5732421875 2.991917682440032
# epoch39#  这般好生厌益，但这般一个人，但这一次便是他们这般，但这般一个女子，但这一次，但见他一个女子，只见他右臂一挥，一柄钢锥，便即向他胸膛，便往地下抓住了他胸膛，只见他左手钢抓，便即向他胸膛，便向他胸膛，便向他
# 1105800 3291651.5810546875 2.976715121228692
# epoch40#  这般一个女子，便是我们师父，你们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？我们是谁？段誉道：你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是
# 1105800 3297074.2758789062 2.9816189870491105
# epoch41#  这般一个女子，只怕我们是谁？段誉道：你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是
# 1105800 3289284.3471679688 2.9745743779779064
# epoch42#  这般一个字画，但见他身形魁梧，一柄短斧，一柄短箭，砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰
# 1105800 3279117.5869140625 2.9653803462778643
# epoch43#  这般一个女子，便即是一个小丫头，便是我们，我们是个个小丫头？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 3266813.044921875 2.954253070104788
# epoch44#  这般一个字画，只觉他身上一阵麻袋，便即停滞，一股劲风，一股劲风，一股劲力，一柄短刀，一柄短刀，一柄短刀，一柄短刀，一柄短刀，一柄短刀，一柄短刀，一柄短刀，一条葱绿缤锥，一条葱绿缤锤，一条葱绿缤黑布，一条
# 1105800 3260371.9375 2.948428230692711
# epoch45#  这般一个字，只见他身穿绿影，一个魁梧，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股劲风，一股
# 1105800 3251671.0458984375 2.940559817234977
# epoch46#  这般一般好汉，但见他一个女子，只是一个大汉人，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉
# 1105800 3245116.5087890625 2.934632400785913
# epoch47#  这般一般好生不错，但这些人都是一般，但这一掌击在他胸口，但见他身子一晃，便即摔倒，只见他胸膛一挺，便即停步，向他扑去，说道：你们是谁？段誉道：你们不肯杀我。段誉道：你们不肯杀我。段誉道：你们不肯杀我。段
# 1105800 3241864.310546875 2.931691364213126
# epoch48#  这般一个女子，这些人都是我们，我们不肯杀我，我们我们也不肯杀我。段誉道：你们怎么办？段誉道：你怎么办？段誉道：你怎么办？段誉道：你怎么办？段誉道：你怎么办？段誉道：你怎么办？段誉道：你怎么办？段誉道：你
# 1105800 3233317.9262695312 2.9239626752301784
# epoch49#  这般一个女子，我们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 3217780.6655273438 2.9099119782305514
# epoch50#  这般一个女子，我们我们是个小丫头，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不是我的，我们也不
# 1105800 3221225.119140625 2.913026875692372
# epoch51#  这般一个字画，但见他身形肌肤，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段
# 1105800 3209892.1635742188 2.902778227142538
# epoch52#  这般一个女子，我们不知他们们也不是？段誉道：你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁
# 1105800 3205413.9399414062 2.8987284680244225
# epoch53#  这般不知这些女子，却也不敢贸然不到，但这些人都是我们，只怕我们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：
# 1105800 3202659.0048828125 2.8962371178176998
# epoch54#  这般一般好玩，不知我们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们
# 1105800 3192432.76171875 2.8869892943739828
# epoch55#  这般好生惭愧，但是不敢贸然不过。段誉道：你们你你这个珍珑，我们我们我们，你们你你们这些人，你还是不肯杀我。段誉道：你们你这位姑娘是谁？段誉道：你们你这位姑娘是谁？段誉道：你们你这位姑娘是谁？段誉道：你们
# 1105800 3189159.7836914062 2.8840294661705608
# epoch56#  这般模样，但这一次便是他们的人物，我们也不是？段誉道：你们这位姑娘是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们不肯杀我。段誉道：你怎么办？段誉道：你怎么办？段誉道：你怎么办？段誉道：你怎么办？
# 1105800 3191463.7939453125 2.8861130348573996
# epoch57#  这般模样，但这一次便是他们武功秘笈，但是以内力不及，但这般一般，但这些人都是一般，但这一次，但见他一个女郎，但他这一掌拍出，但见他一个踉跄，说道：你们你你这位姑娘是谁？段誉道：你说什么？你说什么？你们你
# 1105800 3178306.7412109375 2.874214813900287
# epoch58#  这般好生惭愧，但是不是？段誉道：你们是谁？我们是我们弟子，我们也不知道？段誉道：你们是谁？我们是我们弟子，我们也不知道？段誉道：你们是谁？我们是我们弟子，我们也不知道？段誉道：你们是谁？我们是我们弟子，
# 1105800 3177589.2397460938 2.8735659610653768
# epoch59#  这般好玩？段誉道：你们这位姑娘是谁？段誉道：你们是谁？段誉道：你们这位姑娘是谁？段誉道：你们是谁？段誉道：你们这位姑娘是谁？段誉道：你们是谁？段誉道：你们这位姑娘是谁？段誉道：你们是谁？段誉道：你们这位
# 1105800 3171421.0805664062 2.867987954934352
# epoch60#  这般一个字也不敢贸然，但见他一颗一齐摔倒，只见他脸色苍白，一股劲风，便即停步，便向他胸膛，便即摔倒，只见他脸色苍白，一股劲风，便即停步，便向他胸膛，便即摔倒，只见他脸色苍白，一股劲风，便即停步，便向他胸
# 1105800 3158750.35546875 2.8565295310804397
# epoch61#  这般奇怪，但见他一瞥眼睛一声，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你
# 1105800 3144719.4516601562 2.8438410667934133
# epoch62#  这般好生恼怒，但这一次便是他们是契丹人，我们是我师父，我们是否是我的妻子。段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段
# 1105800 3148896.7973632812 2.847618735181119
# epoch63#  这般好好不是好事，我们是我们弟子，我们是个小丫头，你们还是是不肯杀我。段誉道：你们你你你们这些人，你们还是是不会好玩？你说我们是我们弟子，你们是谁？你们是谁？你们是谁？你们是谁？段誉道：你们你你你们这些
# 1105800 3153667.0043945312 2.851932541503465
# epoch64#  这般一个女子，这些人都是我们，我们是个个小小小子，我们还是不肯杀我。段誉道：你们你不肯杀我。你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？段誉道：你们是谁？段誉道：你们
# 1105800 3139858.2456054688 2.8394449679919234
# epoch65#  这般好是好，我们便是我们弟子，我们也不知道你们，我们也不知道？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？
# 1105800 3144727.6850585938 2.843848512442208
# epoch66#  这般厉害，但见他一个女子，只见他一个踉跄，说道：你们你们是契丹人，我们不知道，你不是我的孩儿，你不是我的孩儿，你不是我的孩儿，你是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁
# 1105800 3129588.076171875 2.8301574210271974
# epoch67#  这般好好不理睬。段誉道：你们你这个珍珑棋局，我们也不必是我们，我们是契丹人，我们不肯杀我。段誉道：你说什么？你们这些人也不是？你说什么？你们这些人，我们不肯杀我。你们是契丹人，我们不肯杀我。段誉道：你说
# 1105800 3132646.2568359375 2.8329230031071964
# epoch68#  这般好手，我们便是我们弟子，我们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们
# 1105800 3127985.2744140625 2.8287079710743916
# epoch69#  这般好手，我们便是我们，我们是契丹人，我们们也不肯杀了我们，你们是我们师父，你们是契丹人，我们们也不肯杀了我们，你们是我们师父，你们是契丹人，我们们们是契丹人，我们们们这些奴婢是契丹人，我们是个个小小丫
# 1105800 3116638.2861328125 2.818446632422511
# epoch70#  这般好生惭愧，但是不是？段誉道：你们你你你这样，你你怎么办？段誉道：你说什么？你说什么？你们这位姑娘，你不是我们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们是谁？你们
# 1105800 3119924.56640625 2.821418490148535
# epoch71#  这般好，我们不肯杀我，我们不是我，我们不肯杀我。你们是契丹人，我们这位姑娘是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是
# 1105800 3110313.6962890625 2.8127271624968913
# epoch72#  这般好，我们不肯杀我，我们不肯杀我。段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们
# 1105800 3107402.0234375 2.810094070751944
# epoch73#  这般好，我们不肯杀我。我们是个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个个
# 1105800 3095891.23046875 2.7996845998089617
# epoch74#  这般好，我们便是我爹爹，你们是谁？段誉道：你们你你你这个个人家，你不肯杀我？你不肯杀我？你不肯杀我？你不肯杀我？你不肯杀我？你不肯杀我？你不肯杀我？你不肯杀我？你不肯杀我？你不肯杀我？你不肯杀我？你不肯
# 1105800 3103956.4399414062 2.8069781515114904
# epoch75#  这般好生惭愧，但是不是？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 3097528.6015625 2.8011653115956774
# epoch76#  这般好好不理睬了。段誉道：你们你这个珍珑棋局，我们也不是？段誉道：你们你怎么办？段誉道：你怎么能够跟你说了。段誉道：你怎么办？段誉道：你怎么能够跟你说了。段誉道：你怎么办？段誉道：你怎么能够跟你说了。段
# 1105800 3092071.7661132812 2.796230571634365
# epoch77#  这般好，我们便是我们，我们是我们师父，你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你
# 1105800 3091980.43359375 2.796147977567146
# epoch78#  这般好生钦佩，但这些人也不知道我们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 3088506.0180664062 2.793005984867432
# epoch79#  这般好，我们便是我们，我们是契丹人，我们这位姑娘是谁？段誉道：你说什么？段誉道：你说什么？段誉道：你说什么？段誉道：你说什么？段誉道：你说什么？段誉道：你说什么？段誉道：你说什么？段誉道：你说什么？段誉
# 1105800 3085032.6357421875 2.7898649265167186
# epoch80#  这般好，我们便是我，我们是我们小姐，你不是我的，我们是我们师父，我们是我，我们是我爹爹，你是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 3073714.3579101562 2.7796295513747116
# epoch81#  这般好，我们便是我们，我们是个个人，我们是否不肯说，我们是个个个个珍珑洒什么？段誉道：你们你不肯跟你们，我们是谁？你们是谁？段誉道：你们你不肯跟你们，我们是谁？你们是谁？段誉道：你们你不肯跟你们，我们是
# 1105800 3067595.8359375 2.7740964332948996
# epoch82#  这般厉害，但见他一瞥的一声，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是
# 1105800 3060195.8369140625 2.7674044464768155
# epoch83#  这般好，我们便是我们，我们是个小丫头，你怎么？你是谁？段誉道：你们是契丹人，我们是个个小贱人，我们是谁？你们们这般是谁？段誉道：你们是契丹人，我们这位姑娘，你是我师父，你们是契丹人，我们这位姑娘，你是我
# 1105800 3072341.087890625 2.778387672174557
# epoch84#  这般厉害，但见他身形矮胖，便是一个女子，只见他脸颊凹凹，将他们抓住了他的脖子，说道：你们你这个珍珑棋局，却也不敢贸然不到，我们是个个小贱人，我们是谁？你们这个小丫头，你不肯跟你们，你们是谁？你们是谁？段
# 1105800 3066904.9819335938 2.7734716783628084
# epoch85#  这般好手，我们便是我们，我们是契丹人，我们这般是什么事？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你
# 1105800 3068226.9682617188 2.774667180558617
# epoch86#  这般厉害，但见他身子一晃，便向他胸膛，便即毙命，只见他脸色苍白，只见他脸色苍白，宛似是桀桀桀傲，宛然是一个苍蝇，只听得喀喇喇一声响，他身子晃出，喀喇喇一声响，一株树枝树堆，塔塔塔塔塔塔塔塔塔塔塔塔塔塔塔
# 1105800 3060009.4916992188 2.767235930276016
# epoch87#  这般厉害，但见到他身子，但见浊，但见他身子一晃，砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰
# 1105800 3053272.1293945312 2.761143180859587
# epoch88#  这般厉害，但见到他身上，但见浊，但见他一个踉跄，但见他一股劲风，便是一股热气，便是一柄蜡烛，蒸韧汹汹，便即软瘫，不由得一阵酸麻，一条麻痒，便即停脚，将他抛在地下，只觉一股暖而缩出，只见他脸上肌肉僵硬，但
# 1105800 3055242.7109375 2.762925222406855
# epoch89#  这般好，我们便是我们武功秘笈，是以他们们是契丹人，我们是个个个个珍珑，我就算是我们，你是我爹爹，你是谁？我们是谁？我们是谁？段誉道：你们是谁？我们是谁？段誉道：你们是谁？我们是谁？段誉道：你们是谁？我们
# 1105800 3054876.7221679688 2.762594250468411
# epoch90#  这般好像一个苍马大元，但我们是个小丫头，你是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你
# 1105800 3046483.3681640625 2.7550039502297543
# epoch91#  这般好好不理？段誉道：你们你说什么？你们们不肯杀我？你说我们是谁？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉
# 1105800 3043455.2329101562 2.752265538895059
# epoch92#  这般好玩？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎
# 1105800 3041451.013671875 2.7504530780176117
# epoch93#  这般好玩？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎么办？段誉道：你们你怎
# 1105800 3044397.6728515625 2.753117808691954
# epoch94#  这般是好，却也不敢贸然不到，但这些人都是不敢贸然，但见他身形一晃，向虚竹拱手裣衽道：你们你怎么办？段誉道：你们你们这位姑娘，你怎么办？段誉道：你们这位姑娘是谁？段誉道：你们是谁？段誉道：你们这位姑娘是谁
# 1105800 3024273.6977539062 2.734919241955061
# epoch95#  这般好，我们不肯杀我。段誉道：你们你怎么办？段誉道：你们你们我们这些畜生，你就算是我们，你怎么办？段誉道：你们你们我们这些畜生，你就算是我们，你怎么办？段誉道：你们你们我们这些畜生，你就算是我们，你怎么
# 1105800 3039719.9677734375 2.7488876539821283
# epoch96#  这般好，我们便是我们，我们是契丹人，我们不肯让你，我们不肯杀了我，你我们不肯娶了，我就算不是你的性命。你们是契丹人，我们是个小丫头，你是谁？你们是契丹人，我们不肯让你，你我们是谁？段誉道：你们你们是谁？
# 1105800 3026548.0463867188 2.736975986965743
# epoch97#  这般好好不理。段誉道：你们不肯杀了。段誉道：你们不肯杀了。段誉道：你们不肯杀了。段誉道：你们你们这些畜生也不是赢，你不是我的性命。段誉道：你们你们这些畜生也不是赢，你不是我的性命。段誉道：你们你们这些畜
# 1105800 3019615.544921875 2.7307067687844775
# epoch98#  这般模样，但他们却也不敢贸然不到，但这些人不敢贸然不知他们们也不敢贸然不知，但这一次便是他们这般，但这般一般，但这些人不知道：你们你怎么办？那女童道：你怎么能嫁了你？你们们这位姑娘，你们是谁？我们是谁？
# 1105800 3020218.3466796875 2.731251896074957
# epoch99#  这般厉害，但见到他身上，但见他一颗一晃，一股劲风，便即停滞，舀，便即停跳，一个一个踉跄，说道：你们你这位姑娘是谁？段誉道：你们这位姑娘是谁？段誉道：你们这位姑娘是谁？段誉道：你们这位姑娘是谁？段誉道：你
# 1105800 3020790.9458007812 2.73176971043659
# epoch100#  这般厉害，但这些人不知道话，我们便是我们，我们是契丹人，我们是个珍珑棋盘，却是我们是契丹人，我们是个珍珑棋盘，却是我们是契丹人，我们是个小丫头，你是谁？你们们也不肯杀我。你们是谁？段誉道：你们是谁？段誉
# 1105800 3014302.2456054688 2.7259018318009303
# epoch101#  这般厉害，但见到他身上已痊愈俱旺。段誉心中怦怦乱跳，心想：我们这些人都是我们眷然，岂能是不是？段誉道：你们我们这些人也不是？段誉道：你们你们这些畜生，你们是谁？段誉道：你们你们这些畜生，你们是谁？段誉道
# 1105800 3023758.1791992188 2.7344530468432073
# epoch102#  这般厉害，但见他一瞥的道：你们是契丹人，我们们也不肯杀了我们，你们是我们师父，我们是个个人不是卑鄙，我也不是我的，我们还是不是？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段
# 1105800 3006831.3950195312 2.7191457723092163
# epoch103#  这般凶霸霸毒，但这一次便是他们这些狐狸，岂能再加惩罚，但我们这些人不能再加，岂能再加，我们便是我们眷然，岂能再加杀我，我也不是？段誉道：你们是谁？段誉道：你们你们这些畜生，你们是谁？段誉道：你们是谁？段
# 1105800 3011000.025390625 2.7229155592246563
# epoch104#  这般厉害，但这些人都是一窍尴尬，但听得砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰
# 1105800 3014685.8012695312 2.7262486898802054
# epoch105#  这般厉害，但见到他身上，但见他一颗一幌，但一股劲风，便即软瘫无措，但他们竟然是一股内力，但见他一瞥的一声响，但见他一瞥眼见到他身上，但见他一瞥的一声响，一股劲力疾踢，喀喇喇一声响，石臼，那矮胖老者的右臂
# 1105800 3008616.9858398438 2.720760522553666
# epoch106#  这般是好事，但这些人不知道：你是谁？你们们们也不肯揍你的话，你还是是我们小姐？你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道
# 1105800 3008718.9208984375 2.7208527047372377
# epoch107#  这般铭隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐
# 1105800 3006795.5629882812 2.71911336859132
# epoch108#  这般是好事，但这些人不知道话，我们便是我们，我们是契丹人，我们这么说，我们是个个小锭银子，我们不肯让你，你怎么办？段誉道：你们怎么不揍你？阿紫道：你们怎么办？阿紫道：你们怎么办？阿紫道：你们怎么办？阿紫
# 1105800 2998593.8271484375 2.711696353000938
# epoch109#  这般希奇古怪，但这些人都是不敢贸然不到，但这一次便是他们这些人一般，只怕不敢贸然不到，只是不敢贸然不到他的手腕，心想：我们这些人都是契丹人，但这些人都是一窍说道：你们我们这些狐狸皆是杨玉蚂蚁，我们也不敢
# 1105800 3008148.6987304688 2.720337039908183
# epoch110#  这般凶霸霸毒，但这时候一瞥之下，但见他一颗一幌，但见浊，只见他脸孔肌肤，便即停步，说道：你们你们这些狐狸，我们不是我，我们是契丹人，我们这些狐狸皆是，我们是契丹人，我们这些狐狸皆是，但我这位姑娘，你们是
# 1105800 3000640.8325195312 2.713547506347921
# epoch111#  这般凶霸霸毒，但这才不敢贸然将他扼死，但见他一颗一瞥眼间，只见他一颗一晃，砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰
# 1105800 2993317.3901367188 2.7069247514349057
# epoch112#  这般铭隐隐隐约约莫非，但他这般一拥而至，但这些人都是一窍，均想：我们是契丹人，我们是个个人，我们是我们师父，你们也不肯杀了我的性命。段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁
# 1105800 2991174.83984375 2.704987194649801
# epoch113#  这般铭隐隐瞒，但是否则我们不知道，我们是否是，我们是个珍珑棋盘，只怕我们这般是我们，我们不肯杀我？你怎么能跟我说话，我怎么能跟我说话，我怎么能跟你说？你怎么也不会跟你说话，我怎么不跟你说？你怎么还是你的
# 1105800 2984385.4907226562 2.6988474323771534
# epoch114#  这般铭隐隐隐约约莫非他的话，但这时一个女子，只见他一个女子说道：这些人，你们是契丹人，我们是个小丫头，你是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段
# 1105800 2992293.7021484375 2.7059990071879523
# epoch115#  这般凶霸霸毒，但是不能再说。段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们
# 1105800 2985592.67578125 2.699939117183261
# epoch116#  这般凶霸霸毒，但是不能贸然不到，但这些武功秘笈，但是以彼之道，还施彼身’，但这些人不能再加，但这些人不能收拾，但这些武功秘笈，却也不敢贸然，但见他一颗一瞥的一声，向他扑去。段誉道：你们是谁？段誉道：你们
# 1105800 2982988.9448242188 2.697584504272218
# epoch117#  这般凶霸霸毒，但是是我们皇帝，我们是契丹人，我们是个粗鲁儒钗。段誉道：你们这位姑娘，你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 2990725.2885742188 2.7045806552488867
# epoch118#  这般凶霸霸毒，但是不能再说。段誉道：你们怎么办？段誉道：你们怎么办？段誉道：你们怎么办？段誉道：你们怎么办？段誉道：你们怎么办？段誉道：你们怎么办？段誉道：你们怎么办？段誉道：你们怎么办？段誉道：你们怎
# 1105800 2985011.83984375 2.6994138540818864
# epoch119#  这般凶霸霸毒，但是不能再说了。段誉道：你们你们是谁？你们们不肯让我们们，你说我你们这位姑娘，我们是契丹人，我们我们这些人，我们也不肯娶了我的性命，我就是你们师父，你们是谁？我们是谁？我们是谁？段誉道：你
# 1105800 2980522.59765625 2.6953541306350606
# epoch120#  这般铭隐隐隐约约莫非，只怕我们都是我们眷然，但是我们武功秘笈，是以他们们这般宜，但只是不肯杀我，岂能再召国国皇帝，我们是契丹人，也不肯杀了他们，我们也不必是我们，我们是个个人人，我也不知道？你们是谁？段
# 1105800 2978082.0541992188 2.693147091878476
# epoch121#  这般铭隐隐隐约约莫非，但他这些人都是我们眷然，但是我们弟子，我们是个个个个人人，我们是个个瞎是契丹人，我们不肯让你们杀了。段誉道：你们说话，我们是个个个个个小贱人，我们是个小小子，你们这个小贼秃，你们不
# 1105800 2973996.6987304688 2.6894526123444282
# epoch122#  这般铭隐隐隐约约莫非，但他这般一个女子说道：这位姑娘，你们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们
# 1105800 2967503.3422851562 2.683580522956372
# epoch123#  这般凶霸霸毒，但是不能再说。段誉道：你们这个珍珑棋局，岂能再加不可。段誉道：你们这个珍珑棋局，岂能再加不可。段誉道：你们这个珍珑棋局，岂能再加不可。段誉道：你们这个珍珑棋局，岂能再加不可。段誉道：你们这
# 1105800 2962755.4624023438 2.6792869075803436
# epoch124#  这般凶霸霸斗，但我们便是我们小姨？段誉道：你们是契丹人，我们是契丹人，我们们也不肯杀了我的性命，我们也不知道？你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你
# 1105800 2977815.3154296875 2.692905873964268
# epoch125#  这般凶霸霸斗，但我们这些狐狸嘛，我们这个珍珑棋局，但是我们武功秘笈，不知我们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们说话，你们是谁？段誉道：你们这个珍珑棋局，但是我们武功秘笈，是谁？段誉道
# 1105800 2970203.1450195312 2.6860220157528767
# epoch126#  这般凶霸霸毒，但是不是赢，他们是契丹人，也不肯杀了我们，我们不肯杀我，我们也不肯杀了我的性命。段誉道：你们你们这位姑娘，你们是契丹人，我们这位姑娘，我们是契丹人，我们这位姑娘，我们是契丹人，我们这位姑娘
# 1105800 2966573.8408203125 2.6827399537170487
# epoch127#  这般铭隐隐隐约约莫非他的话，但这些人都是我们皇宫耆宿派人的武功，但这般一般不是，岂能贸然，我们是契丹人，也不能杀了我的性命，我们是我们师父，我们是契丹人，我们这些人也不是我的朋友。段誉道：你们是谁？段誉
# 1105800 2970874.4243164062 2.686629068833791
# epoch128#  这般凶霸霸毒，但这时候便是我们们，我们是我们小姐人的晦气，我们也不必再说，我们是我们师父，我们不肯娶了驸马，我们是我们师父，我们是我们小姐人，我们是个个个个小丫头，我们我们是我们琅擐扌’的闺女，我们是我
# 1105800 2962753.8232421875 2.679285425250667
# epoch129#  这般凶霸霸毒，但是不能再说。段誉道：你们你们这些畜生，你们是个个瞎，我们不肯杀我？你们们这些狐狸永远远远，你们是个珍珑，这位姑娘是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们怎么办？段誉道：你们
# 1105800 2967924.6806640625 2.6839615488009247
# epoch130#  这般铭隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐
# 1105800 2960240.3076171875 2.677012396108869
# epoch131#  这般咄咄咄咄，却不是不是，但这时一颗心怦怦乱跳，一颗一怔，说道：你们你这个珍珑棋局，岂能再加，我们是我们这些人，我们是个耕斯，我们也不妨不去，我们也不妨你们们，你们是谁？段誉道：你们这位姑娘，你们是谁？
# 1105800 2959963.6000976562 2.676762163228121
# epoch132#  这般凶霸霸毒，但是不是？段誉道：你们是契丹人，你们这样，你们是谁？你们这样？你们们这样？你们们们们我们，你们是契丹人，你们这些畜生，你们也不是？你们这些畜生，你们也不是？你们这些畜生，你们也不是？你们这
# 1105800 2959519.4501953125 2.6763605084059616
# epoch133#  这般铭隐隐隐隐隐隐约约莫道：你们是谁？段誉道：你们我们这些狐狸勾了，我也不是你们，我们是个不是，我们我们这些人也不是我的性命，我们是我爹爹，你们是谁？段誉道：你们我们这些狐狸勾了，我也不是你们，我们是个
# 1105800 2957108.8852539062 2.67418057990044
# epoch134#  这般铭隐隐瞒，但只是我们武功秘笈，是否是契丹人，我们是个个人物，只是我们琅擐扌’、我，你是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 2959455.6689453125 2.676302829576155
# epoch135#  这般铭隐隐隐隐隐隐约约约莫非道：我们是个丑绝技，我们是个耕福武林盟主，却是我们少林寺，我们是个耕存，那位姑娘，你们是契丹人，我们是个个狐媚年来，我们是否是，我们是个耕存，我们是契丹人，我们是个粗鲁儒钗，
# 1105800 2952652.1552734375 2.6701502579792344
# epoch136#  这般铭隐隐瞒，但是否则我们不肯娶了驸马，我们是我们小姐，我们不肯娶了驸马，我们也不肯杀了他们，我们也不肯杀了我的性命，我们是我们小姐，你说话，我们是个个人物，只怕我们这些人，我们是个个人物，但我们这些人
# 1105800 2940790.7041015625 2.659423678876436
# epoch137#  这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，
# 1105800 2952471.7749023438 2.6699871359218155
# epoch138#  这般凶霸霸毒，却也不敢贸然不懂，我们便是我们，我们是契丹狗贼，我们是个耕读来，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗贼，我们是契丹狗
# 1105800 2948942.5786132812 2.6667956037378198
# epoch139#  这般凶霸霸毒，但是不能再说，但见他一颗一齐跃出几步，只觉一股剧烈，显然是一片倦气，但见他一颗一齐跃起，便即摔跌下，只见他脸色苍白，只见他一股劲力翻而落入，便即停脚，将他抛在一旁，只觉他一颗一勒，便即停步
# 1105800 2948326.5297851562 2.666238496821447
# epoch140#  这般凶霸霸毒，但是不能再找了。段誉道：你们你这样癞虾蟆不是谁？你们们们给我杀我。段誉道：你们这位姑娘，你们便是我师父，我们是契丹人，我们是个耕存，我们这位姑娘，你们是契丹狗贼，我们是契丹狗贼，我们是契丹
# 1105800 2943752.2309570312 2.662101854726923
# epoch141#  这般铭隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐隐约约莫道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 2942142.2998046875 2.6606459575010737
# epoch142#  这般凶霸霸毒，我们我们这些狐狸永远远远迎接去去，便即冻涌，一个馒头上，一阵寒气，砰砰砰砰砰砰砰砰砰砰砰砰砰插矛矛锏，一柄火焰，一柄蓝纷纷飞，显然不由，只见他一股劲风，便即停步，说道：你们是契丹人，我们我
# 1105800 2939916.6293945312 2.6586332333103013
# epoch143#  这般铭隐茫然，但见他一瞥眼见到他身上，但见他一瞥的一声，说道：我们是契丹人，我们是个个人，我们是契丹人，我们是个个瞎是禽兽，不知我也不是？段誉道：你们不肯胁迫，我们是个个瞎是契丹人，我们不肯胁迫，我们是
# 1105800 2945325.6528320312 2.6635247357858844
# epoch144#  这般铭隐隐隐隐隐隐约约莫非，但他们却是我们武功秘笈，是否是武林盟主，也决计不能让他们杀了。段誉道：你们是谁？段誉道：你们是谁？段誉道：你们不肯胁迫，我们们也不肯杀了你的性命，我们是我们师父，你们是契丹人
# 1105800 2942307.0888671875 2.660794979984796
# epoch145#  这般铭隐茫然，但这些人都是一窍说出，但见他一瞥眼泪，心想：我们是契丹人，我们是个个人，我们是个耕存魔子的事，我们是个个人，我们是个个人，我们是个个脓包货色，我们们这些人都是我们佼佼佼佼，我们是否是了。段
# 1105800 2940189.8500976562 2.6588803129839538
# epoch146#  这般铭隐隐隐隐隐隐约约约莫非不懂，但这些人都是我们弟子，但是不是赢，我们是契丹人，我们是个个坏人，我们是契丹人，我们是个个脓包叠妾，我们是我们这些人，我们是个耕存人家，你是谁？段誉道：你们这个珍珑棋局，
# 1105800 2934839.984375 2.6540423081705553
# epoch147#  这般凶霸霸毒，但是不能再找他，但见他一瞥的一声，说道：我们是契丹人，我们是个个坏人，我们是契丹人，我们是个个坏人，我们是个个人，我们是个耕存，你们这位姑娘，我们是个耕存，那么我们这些人，我们是个耕存，你
# 1105800 2932212.009765625 2.6516657711752805
# epoch148#  这般铭隐茫然，但见他一瞥眼见到他狰狞，只见他一颗一沉沉响，一柄晶莹裹住，喀喇喇一声响，板斧，两株岩石，将一条条绿火刀插入他腰间，宛似，只见他脸上肌肉僵硬，但一片漆黑，便即停桨，便往地下，只觉一股热血，便
# 1105800 2937515.5751953125 2.656461905584475
# epoch149#  这般铭隐隐隐隐隐隐约约约莫非他的吩咐？段誉道：你们我们这些人一般，我们是个耕存，你们这个小姑娘，我们是个个脓血，我们我们不肯杀我。你们这样？你们不肯杀我？你你你我们们这些狐狸都是胭脂膏繁，是癞虾蟆如毋，
# 1105800 2933697.708984375 2.6530093226481957
# epoch150#  这般铭隐茫然，但这些人不知道话，我们是否是诬蔑假惺惺，但这些人不知他们是否认输？段誉道：你们是契丹人，我们是个个脓包货色，你们不肯杀了你。你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 2930495.3623046875 2.6501133679731304
# epoch151#  这般铭隐茫然，但见他一颗一个踉跄，一柄钢杖拄地，右手一抄，右手钢锥踢住了他胸口，只见他脸色苍白，只见他一股劲风，便即冻涌，嗤嗤嗤嗤，砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰砰射掷去，喀喇喇一声响，石凳上绣了葫芦，
# 1105800 2935852.6728515625 2.654958105309787
# epoch152#  这些人都是我们，我们是契丹人，我们不肯娶了驸马，我们也不妨你们，我们是个耕款，我们是契丹人，我们不肯娶了驸马，我们是个耕款，我们是契丹人，我们不肯娶了驸马，我们是个耕款，我们是契丹人，我们不肯娶了驸马，
# 1105800 2938676.4638671875 2.657511723518889
# epoch153#  这般铭隐隐瞒上乘内力，虽然罕有，但这些人都是一窍说道：你们我们是契丹人，我们是个小瓶子，不知我们是个小小贼秃？我们不肯杀了。我们是个个蛮烦考仇，你你怎么办？段誉道：你们是谁？段誉道：你们是谁？段誉道：你
# 1105800 2928249.0522460938 2.6480819788805334
# epoch154#  这般铭隐隐隐隐隐隐约约约莫非，但他既是我们弟子，但是以彼之道，还施彼身’，我们也不必是我们弟子，岂能再加审矣，我们是契丹人，我们是个小丫头，你说什么？你们说话，你们不肯杀了。段誉道：你们不肯胁迫，我们们
# 1105800 2929542.4057617188 2.6492515877751117
# epoch155#  这般铭隐隐隐隐隐隐约约约莫非是，但这些人都是我们眷然，岂能再加，我们是契丹人，却也不妨。段誉道：你们不妨，我们这些人都是我们侄儿，你们我们这些人，我们是个个人，我们是契丹人，我们这些狐狸永远远远迎接去去
# 1105800 2915919.2045898438 2.6369318182219605
# epoch156#  这般铭隐隐瞒了他们武功高强，却也不敢贸然不过，我们是个个小锭银子，我们我们是契丹人，也不是紧，我们是个小丫头，你怎么？段誉道：你们这个珍珑棋局，却不能杀我？段誉道：你们不肯杀了你的性命，我们还是不肯杀我
# 1105800 2924573.458984375 2.644758056596469
# epoch157#  这般铭隐茫茫和他们是否认输？段誉道：你们是个个丑陋田小姐，你是谁？你们们们跟你说话，我们是我们这些人，我们是个耕存人家，我们是契丹人，我们是个珍珑，这位姑娘是谁？段誉道：你们是谁？段誉道：你们是谁？段誉
# 1105800 2925045.8666992188 2.6451852655988595
# epoch158#  这般铭隐隐瞒了他们，我们是个珍珑，这些人不是癞虾蟆不希事？段誉道：你们是个耕政迳样，我们是个耕存魔子的朋友，我们是个耕存魔子的事，我们是个个人，我们是个耕福奴婢，你们也不知道？你们是谁？段誉道：你们是谁
# 1105800 2926905.978515625 2.6468674068688958
# epoch159#  这些奴才不知这些男子，我们是个个脓包衫子，我们这些小丫头，你跟你说话，你们不肯让你们，你们不肯娶了驸马，我们我们们我们，我们是个耕存魔子的事，我们是个小小娃娃！段誉道：你们你们这些畜生，你们我们这些狐狸
# 1105800 2918096.03515625 2.638900375435205
# epoch160#  这般好，却是一个个便宜，便是不能收拾，但见他一颗一个踉跄，便即摔倒，只见他脸色苍白，只见她皓亮黏在她胸口，便即踹在她身畔，但见她脸色惨白，但见他一股劲风，便即冻涌，宛似，只见他脸色一沉极快，只见他脸色苍
# 1105800 2918079.2563476562 2.638885201978347
# epoch161#  这般铭隐茫然，但见他一瞥眼见到他身上，但见他一股劲风，便即冻涌涌入尺许，只见他脸上肌肉痉挛，但见浊，只见他脸颊一麻，只觉一股热血，便即停步，向他扑去。段誉道：你们你们这些畜生也是不是？你们们们不肯娶了驸
# 1105800 2922890.8901367188 2.6432364714566097
# epoch162#  这些人都是铭心时铭感，但见他一瞥的道：你们你们这位姑娘，你们是契丹人，我们我们们这些人，我们是个个脓包货私，我们我们这些人都是我们，你说我们这位姑娘，你们是契丹人，我们我们是契丹人，我们我们们这些人，我
# 1105800 2912241.109375 2.6336056333649847
# epoch163#  这般铭隐茫然，但见他这般渗出一条黑黝黝黝黝黝蜂，便是这般，但一个女子，只见他钓杆，只见他右颊凸凸，便即熄了，只见他右手拇指，便即抛在她背上，只觉他身子一幌，宛似躺在床上，说道：你怎么办？段誉道：你们不肯
# 1105800 2917941.1586914062 2.6387603171381864
# epoch164#  这般凶霸霸毒，我们我们这些人都是我们佼莉榜历，我们是契丹人，我们我们这些人，我们是个个人，我们是契丹人，我们不肯娶了驸马，我们这些人也不肯娶了我的性命，我们是我们师父，你们是契丹人，我们是个个人，我们是
# 1105800 2905568.240234375 2.627571206578382
# epoch165#  这般凶霸霸毒，但是我们，我们是契丹人，我们不肯杀了。我们是契丹人，我们是契丹人，我们是契丹人，我们是契丹人，我们是契丹人，我们是个个蛮夷奴仆？段誉道：你们你们这些人，我就算绑绑绑了。段誉道：你们你们这些
# 1105800 2914884.4907226562 2.6359961030228396
# epoch166#  这般铭隐茫然，但见他一瞥眼见到他狰狞，只见他一股劲风飞舞，便往他胸口，便即毙命，但见他身形便湿，一股浑厚，只觉他一颗一沉，一股暖，便是一团漆黑，但见他一颗一恻漆黑布皮，只见他皓亮黏沉，一片漆黑，便即软瘫
# 1105800 2916485.634765625 2.6374440538665445
# epoch167#  这般铭隐茫茫之极，只听得呀呀一遍，呛啷啷洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋洋桥，宛似，宛然是一个乞丐揣死，但见他一颗一个踉跄，一股劲风跃动，左手钢锥踏入窗纸，便即软瘫狭隘，说道：你
# 1105800 2909126.3833007812 2.630788915989131
# epoch168#  这般铭隐隐隐约约得午时候，但见他一颗一个踉跄，一柄地头，右手一探，喀喇喇一声响，他右手抓住了他胸口膻中穴，一股浑厚劲力，只觉他胸膛，只觉他一颗一沉，左手钢锥挥出了瓷瓶，嵌在桌上一根一拐，一柄锏来掉在地下
# 1105800 2909174.193359375 2.6308321517086046
# epoch169#  这般铭隐茫然，均想：这个珍珑，但这些人都是我们眷然，岂能再加审夺，但是以他们们是我们皇帝，你们是契丹人，也不知他们们们们们这些脓包货真，我们这些人也不肯娶了驸马，我们是我嫂子？段誉道：你们说话，你们是谁
# 1105800 2908018.6469726562 2.629787164923726
# epoch170#  这般凶霸霸斗，却也不敢贸然捋虎偷偷，便即摔在她胸口，只见他脸上肌肉僵硬，但见他一颗一瞥的一声，向他肩头，便向他胸膛，便即毙命。段誉道：你们是谁？段誉道：你们说话，你们是谁？你们们这些狐狸勾了。段誉道：你
# 1105800 2911067.435546875 2.632544253524032
# epoch171#  这般铭隐茫然，但听得铿铿锵锵锵锵锵锵锵锵锵锵锵锵锵锵锵渺蚁浩作，那人一个女子，说道：你们你们这些狐狸勾了，你们你们便是我们小姐，你是谁？你们们这些狐狸勾了，你就算我们们这位姑娘，你们便是我们，你是我爹爹
# 1105800 2910469.2709960938 2.632003319764961
# epoch172#  这般铭隐茫然，但见他一个女儿是少林寺，只怕他们的武功，但这些人都是我们眷然，岂能再加审鉴，我们这位姑娘，我们不是我们，我们是个个人人家，我们这些人人家是个人物，我们是个狐绡晋米锦缎拓葛，巽，你们是契丹人
# 1105800 2918235.32421875 2.639026337691038
# epoch173#  这般铭隐茫然，但见他一个女子，一个蒲团，只见他皓亮，映在炕底，便即毙命，但见他身子一晃，喀喇喇一声响，他左手抓住了他胸口，便即毙命，但见他一瞥眼间，只见他一颗一晃，砰砰砰砰砰砰砰砰砰砰砰砰砰砰横插起一柄
# 1105800 2908478.673828125 2.630203177634405
# epoch174#  这般铭隐茫茫之极，只听得蹄声笞笞蓬蓬，腾腾腾腾，喀嚓一声响，他一颗一幌，右手一挥，将他肩头掷去，右手抓住他胸膛，便即毙命。段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：
# 1105800 2906074.1704101562 2.6280287307018955
# epoch175#  这般铭隐茫然，但见他这般一齐睁开冰块，喀嚓喇喇喇一声响，溪水，喀喇喇一声响，桌上琉璃褪峰，右手捻久，右手钢杖绕着一个女子的辔头，便即停步，说道：启禀公主，我们是契丹人，我们是个粗鲁契丹人？段誉道：你们是
# 1105800 2891524.5107421875 2.614871143735022
# epoch176#  这般铭隐茫然，但这时一个女儿，只是一个时辰，便即矫捷，只是一股劲风缭绕，宛似已然，但见他一颗一晃，喀喇喇一声响，屋宇辉住，便即蠕蠕迸泻，但见他一颗一幌，只觉一股暖，一柄火焰，映到他身旁，只见他脸色鲜血淋
# 1105800 2893063.47265625 2.616262861870365
# epoch177#  这般铭隐茫然，但这些人不知道，但这些人也不是我，我们是个个人，我们是个耕婚仙子，你们是契丹人，我们是个小丫头，你们还是不肯杀我。你们是契丹人，我们是个个蛮夷男子？你怎么还是我的孩儿，你怎么办？段誉道：你
# 1105800 2899740.9311523438 2.6223014389151236
# epoch178#  这些猥琐，还是不是这个人，我怎么能够，我也不肯杀了你。你们是谁？段誉道：你们怎么办？段誉道：你怎么不肯让你们，你怎么办？段誉道：你怎么不跟你说话，我们怎么会不跟你说话，我们你怎么办？段誉道：你们怎么办？
# 1105800 2898029.1801757812 2.6207534637147596
# epoch179#  这般凶霸霸狠狠，道：你怎么不能让我们杀了。你们们这些狐狸永远远远迎接，不论这些奴隶，却也不枉你，你们不肯让你们杀了。你们是谁？你们这些狐狸勾了。段誉道：你们不肯让你们，你们这些狐狸勾了。段誉道：你们不肯
# 1105800 2901843.185546875 2.6242025552060726
# epoch180#  这般铭隐茫然，但见他这般一把汗水炭牙，便在这里，只觉他身形一晃，便往地下爬出，右手钢抓飞舞，便即翻涌，喀喇喇一声响，一条绿杉阔滑，砰砰砰砰响出，砰砰砰砰砰砰砰砰砰砰砰砰砰砍掷出，颏下铺裂，便被他抓住了他
# 1105800 2902557.2124023438 2.6248482658729824
# epoch181#  这般铭隐茫茫之态，但这些人都是我们哲罗星、玄难、汪帮主、邓百川等都是一惊，心想：这些人不是赢，我们是我们小姐？你们我们是我们小姐？你们我们是我们小姐？你们我们是我们小姐？你们我们是我们小姐？你们我们是我
# 1105800 2896766.7641601562 2.619611832302547
# epoch182#  这些人都是我们，我们是个耕政，我们是契丹狗贼，我们是个珍珑腥煎，我们是契丹狗党，只怕我们一个个人也不敢贸然不睬。段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？
# 1105800 2900928.7568359375 2.62337561659969
# epoch183#  这般凶霸霸狠狠，说道：你们怎么办？段誉道：你们这个珍珑棋局，却不是你们，我们是个珍珑，我们们这位姑娘是谁？段誉道：你们不肯娶了驸马，我们也不是你的爸爸。你你你你们这个小丫头，你说什么？你怎么办？段誉道：
# 1105800 2898153.2353515625 2.6208656496215976
# epoch184#  这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄，但这般咄咄轻轻，但这一次便是一般，但这般咄咄，但这般迅捷巧妙，但这些人都是铭隐隐隐隐隐隐隐隐隐隐
# 1105800 2897629.8125 2.62039230647495
# epoch185#  这般铭隐茫然，但这些人不知得罪，但这些人都是不是我们们，我们便是我师父，我们是个小丫头，你说话，你们是我爹爹，你怎么办？段誉道：你们不肯胁迫，我就算不是我的性命，我就是你爹爹，你怎么办？段誉道：你们不肯
# 1105800 2888903.8955078125 2.6125012619893404
# epoch186#  这些人都是我们，我们不肯娶了驸马，岂能说话，我们也不敢违拗，我们也不敢违拗，我们也不敢违拗，我们也不敢违拗，我们也不敢违拗，我们也不敢违拗，我们也不敢违拗，我们也不敢违拗，我们也不敢违拗，我们是个坏人？
# 1105800 2902170.39453125 2.6244984577059594
# epoch187#  这般凶霸霸毒，但是不能不是我们，说道：你们不肯娶了驸马，呒不知他们是谁？段誉道：你们说话，你们是谁？段誉道：你们说话，你们是谁？段誉道：你们说话，你们是谁？段誉道：你们说话，你们是谁？段誉道：你们说话，
# 1105800 2888685.8662109375 2.6123040931551254
# epoch188#  这般凶霸霸狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠狠
# 1105800 2888973.5517578125 2.6125642537147877
# epoch189#  这般铭隐茫然，但这些人都是铭心刻断，但他身上宛似，只见他脸上肌肉僵硬，却也不敢怠慢，只见他脸上肌肉僵硬，只见他一股劲风，便即停步，说道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段
# 1105800 2892414.1586914062 2.6156756725369923
# epoch190#  这般凶霸霸狠狠，道：你怎么办？段誉道：你们这个珍珑棋局，却不是你们，我们是个个个瞎，你们是个耕亥列岁戚容，便是我们琅擐扌’的朋友，却也不敢贸然杀了。段誉道：你们这位姑娘是谁？段誉道：你们是谁？段誉道：你
# 1105800 2891739.5029296875 2.6150655660424014
# epoch191#  这般凶霸霸狠狠狠狠狠狠狠辣丸丸，哀求，你们不肯娶了驸马，我们也不肯杀了我的性命，我也不知道？你们是谁？段誉道：你们这个珍珑棋局，却也不妨？段誉道：你们是个耕婚陵人？我们是契丹人，我们是个个人，我们是个耕
# 1105800 2889449.7709960938 2.6129949095642013
# epoch192#  这些人都是我们们，我们不肯娶了驸马，我们也不是我的徒儿，你怎么办？段誉道：你们是个耕政，你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是谁？段誉道：你们是
# 1105800 2884549.267578125 2.6085632732665265
# epoch193#  这些人都是我们，我们不肯娶了驸马，我们也不肯杀了我的性命，我就是我爹爹，你怎么办？段誉道：你们说话，你们是我师父，我们是我们这些人，我们是契丹人，我们不肯娶了驸马，我们也不用不睬。段誉道：你们说话，你们
# 1105800 2886791.1918945312 2.6105906962330723
# epoch194#  这些人都是我们们，我们不肯杀了。我们是契丹人，我们我们这些人一个女子，我们是契丹人，我们我们这些奴才也不能杀了我。你们你们我们这些奴仆，我们是不肯杀我？段誉道：你们这个珍珑棋局，却也不妨？段誉道：你们是
# 1105800 2883635.0629882812 2.6077365373379284
# epoch195#  这般铭隐茫然，但听得嗤嗤嗤声响，一缕蓝园垮钉中掠去。他心中怦怦乱跳，心想：我们这些珍珑棋局，岂能不是，我们便是我嫂子，你们也不肯杀了我们，我们是个耕存个珍珑，但这些人，岂能贸然不臻，我们也不必是我们朋友
# 1105800 2881705.2905273438 2.6059914003683704
# epoch196#  这般铭隐茫茫和他们不知他们是否认得紧，却也不敢贸然回答，说道：你们不肯娶了驸马，我们也不妨你们，你怎么办？段誉道：你们不肯跟你们，我们是个癞虾蟆不是癞虾蟆不能换我，我们不肯跟你说，我们不肯杀我？段誉道：
# 1105800 2884521.5395507812 2.608538198183018
# epoch197#  这些猥琐，还是不是我们的，我们便是我师父，我们是个珍珑，我们们我们是个狐绡岁，你们不肯跟你说，我们不肯杀了。我们说话，你们是我师父，我们是个耕斯大恶人物？段誉道：你们是个耕读宾馆，只听得呀呀一声，砰砰砰
# 1105800 2879815.3813476562 2.604282312667441
# epoch198#  这般畏惧凄厉害死，但这一次不是雌人家搬断了。段誉道：你们是个丑肖狐缤子，你们是我爹爹，你们这些人，我们是个癞虾蟆不会愚蠢，你怎么没有，我们是我们这些人，我们是个癞虾蟆不会愚蠢，你怎么能嫁了你？你们这样？
# 1105800 2876577.7939453125 2.6013544890082407
# epoch199#  这般凶残猛璃价，纯熟，但他们竟是预备，说道：你们是谁？段誉道：你们是谁？段誉道：你们不肯让我们，你们是我们这些畜生，你们是契丹人，我们我们不肯让我宰割，我们便是我们舅母，我们不是我们，我们是契丹人，我们
# RNN(
#   (CharEmbed): Embedding(3601, 30)
#   (rnn): GRU(30, 300, num_layers=2, batch_first=True, dropout=0.1)
#   (layers): ModuleList(
#     (0): Linear(in_features=300, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=64, bias=True)
#     (2): Linear(in_features=64, out_features=128, bias=True)
#   )
#   (out): Linear(in_features=128, out_features=3601, bias=True)
#   (non_linear): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
sample = generate(model, seed="第一", n=100)
print(sample)
# Out:
# 第一个铭下一团漆黑，说道：你们不肯娶了驸马，我们也不用好了。段誉道：你们不肯让我杀了。段誉道：你们不肯让我瞧瞧，我们我们不肯杀我？你们们我们是我们我们这个珍珑棋局，却也不妨。段誉道：你们不肯让我杀了。段誉

# %% [markdown]
# ## Character Language Model
# 1. Upload the 'tlbb.txt' corpus into the colab notebook and sart running. The corpus has 1 million chinese characters and approximately 4000 different chinese characters.
# 2. Collect all the characters with frequency rank bigger than Max_Vocab and map it to '\<unk\>' character.
# 3. After adding weight to nn.CrossEntropyLoss, the model can generate chinese sentences character by character.
# 4. GRU and LSTM both perform better than vanilla RNN
